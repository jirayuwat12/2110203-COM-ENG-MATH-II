# %% [markdown]
# # **<<< Only Problem 1 and 2 will be graded >>>**

# %% [markdown]
# ## Problem 1 (sound)
# Denoising time with FFT (DFT)

# %%
# %pip install praat-parselmouth
# %pip install librosa
# %pip install parselmouth
# Out:
# Requirement already satisfied: praat-parselmouth in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (0.4.3)
# Requirement already satisfied: numpy>=1.7.0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from praat-parselmouth) (1.24.4)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: librosa in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (0.10.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (4.7.1)
# Requirement already satisfied: audioread>=2.1.9 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (1.3.0)
# Requirement already satisfied: decorator>=4.3.0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (0.3)
# Requirement already satisfied: pooch>=1.0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (1.7.0)
# Requirement already satisfied: scipy>=1.2.0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (1.11.1)
# Requirement already satisfied: joblib>=0.14 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (1.3.2)
# Requirement already satisfied: msgpack>=1.0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (1.0.5)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (1.24.4)
# Requirement already satisfied: soxr>=0.3.2 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (0.3.6)
# Requirement already satisfied: numba>=0.51.0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (0.57.1)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from numba>=0.51.0->librosa) (0.40.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from pooch>=1.0->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: packaging>=20.0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from pooch>=1.0->librosa) (23.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting parselmouth
#   Using cached parselmouth-1.1.1.tar.gz (33 kB)
# Collecting googleads==3.8.0
#   Using cached googleads-3.8.0.tar.gz (23 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/5g/160h3py942nb4pbbgy0dhtz40000gn/T/pip-install-fuk_06p2/googleads_f96aea2a04e44005b303fc438e9b5c0d/setup.py'"'"'; __file__='"'"'/private/var/folders/5g/160h3py942nb4pbbgy0dhtz40000gn/T/pip-install-fuk_06p2/googleads_f96aea2a04e44005b303fc438e9b5c0d/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/5g/160h3py942nb4pbbgy0dhtz40000gn/T/pip-pip-egg-info-9cf5lcem
#          cwd: /private/var/folders/5g/160h3py942nb4pbbgy0dhtz40000gn/T/pip-install-fuk_06p2/googleads_f96aea2a04e44005b303fc438e9b5c0d/
#     Complete output (1 lines):
#     error in googleads setup command: use_2to3 is invalid.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/fa/f8/f84ad483afaa29bfc807ab6e8a06b6712ee494a2aad7db545865655bdf99/googleads-3.8.0.tar.gz#sha256=742b244f2b6307c583e74fff295c84ef9507983dbeba482cbd0840b90ebda573 (from https://pypi.org/simple/googleads/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Collecting parselmouth
#   Using cached parselmouth-1.0.2.tar.gz (33 kB)
#   Using cached parselmouth-1.0.1.tar.gz (37 kB)
#   Using cached parselmouth-1.0.0.tar.gz (33 kB)
#   Using cached parselmouth-0.5.tar.gz (33 kB)
#   Using cached parselmouth-0.4.tar.gz (33 kB)
# ERROR: Cannot install parselmouth==0.4, parselmouth==0.5, parselmouth==1.0.0, parselmouth==1.0.1, parselmouth==1.0.2 and parselmouth==1.1.1 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     parselmouth 1.1.1 depends on googleads==3.8.0
#     parselmouth 1.0.2 depends on googleads==3.8.0
#     parselmouth 1.0.1 depends on googleads==3.8.0
#     parselmouth 1.0.0 depends on googleads==3.8.0
#     parselmouth 0.5 depends on googleads==3.8.0
#     parselmouth 0.4 depends on googleads==3.8.0
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/user_guide/#fixing-conflicting-dependencies
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Users/jirayuwat/Desktop/2110203-COM-ENG-MATH-II/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from scipy import signal,fftpack
import cv2
from skimage.io import imread
import matplotlib.pyplot as plt
import IPython.display as ipd
import os

import librosa
import parselmouth

# %%
sampling_rate = 32000
N=10001
Nf = 3 # Nf--> num freq
t= np.arange(N,dtype=float)
# pick rand period betwwen 10-2010 and convert to freq

# random period
Ts = np.random.rand(Nf)*2000+10
fs=1/Ts

# fs in sampling rate = 32000
fs_real = fs*sampling_rate

# pick rand Amp and phase
amp = np.random.rand(Nf)*200+ 100
phi = np.random.rand(Nf)*2*np.pi

# create clean signal
h = np.zeros(N)
for i in range(len(fs)):
    h += amp[i]*np.sin(2*np.pi*fs[i]*t + phi[i])

# signal with noise
h_w_noise = h + np.random.randn(N)*3*h + np.random.randn(N)*700

# %%
def plot_signals(signals = [],
                 titles = []
                ):
    if len(titles) != len(signals):
        if len(titles) != 0:
            raise ValueError
        else:
            titles = [f'untitled {i}' for i in range(len(signals))]

    plt.figure(figsize=(20, 10))
    for idx, (s, t) in enumerate(zip(signals, titles)):
        plt.subplot(len(signals), 1, idx+1)
        plt.plot(np.linspace(0, len(s), len(s)),s)
        plt.grid()

        plt.title(t)

# %%
# TODO 1.1 : plot (1) clean signal and (2) noisy signal with label
plot_signals(signals=[h, np.fft.fftshift(np.fft.fft(h)), h_w_noise],
             titles=['clean', 'clean FFT', 'noised'])

# %%
# TODO 1.2: plot magnitude of FFT of the noisy signal (freq sort form min--> max)

h_w_noise_fft = np.fft.fft(h_w_noise)
h_w_noise_fft_shifted = np.fft.fftshift(h_w_noise_fft)
h_w_noise_fft_shifted_magnitude = np.log(1 + np.abs(h_w_noise_fft_shifted))

h_w_noise_fft_one_side = h_w_noise_fft_shifted[len(h_w_noise_fft_shifted)//2:]
h_w_noise_fft_one_side_magnitude = np.abs(h_w_noise_fft_one_side)

plot_signals(signals=[h_w_noise_fft_one_side, h_w_noise_fft_one_side_magnitude],
             titles=['noised FFT one side', 'noised Magnitude FFT shifted'])

# %%
# TODO 1.3 : cleaning the noisy signal using magnitude of FFT

D0 = 100
filter_arr = np.ones_like(h_w_noise_fft_one_side)
filter_arr[D0:] = 0

h_w_noise_fft_filtered = h_w_noise_fft_one_side * filter_arr
h_w_noise_filtered = np.fft.ifft(h_w_noise_fft_filtered)

# %%
# TODO 1.4 : plot clean signal, noise signal and filtered signal (from your result in TODO 3.3) with label


plot_signals(signals=[h, h_w_noise, h_w_noise_fft_filtered, h_w_noise_filtered],
             titles=['Original signal', 'Noised signal', 'FFT signal after filtered', 'Signal after filter'])

ipd.Audio(h_w_noise_filtered, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# TODO 1.5 : export with IPython.display, listen to (1) original signal (2) signal with noise (3) signal after filtered

# %%
# TODO 1.6 : Write to explain and analyze the results

# %% [markdown]
# ## Problem 2 (image FFT)
# Download a 1000 x 1000 image ("hamtaro.png") below
#
# <a href="https://ibb.co/kHTjZbb"><img src="https://i.ibb.co/kHTjZbb/hamtaro.png" alt="hamtaro" border="0"></a>

# %%
# !wget -nc 'https://i.ibb.co/kHTjZbb/hamtaro.png'
# Out:
# File ‘hamtaro.png’ already there; not retrieving.

# %%
screen_shot = cv2.imread('hamtaro.png',0)

plt.figure(figsize=(10,10))
plt.imshow(screen_shot, cmap='gray')
plt.show()

# %%
# Apply FFT to the given image
F1 = fftpack.fft2((screen_shot).astype(float))
F2 = fftpack.fftshift(F1) # FFT center zeros freq
plt.figure(figsize=(10,10))
plt.imshow( (20*np.log10( 0.1 + np.abs(F2))).astype(int), cmap=plt.cm.gray)
plt.show()

# %%
# TODO 2.1 : Implement an ideal high-pass filter with a box size of 100x100 pixels on the given image
n = 100
image_size = F2.shape
x, y = np.mgrid[-image_size[0]//2:image_size[0]//2, -image_size[1]//2:image_size[1]//2]

hp_filter = np.ones_like(F2, dtype=np.int16)
hp_filter[(x<n//2) & (x>-n//2) & (y<n//2) & (y>-n//2)] = 0
hp_filter = np.real(hp_filter)
plt.subplot(2, 2, 1)
plt.title('high pass filter')
plt.imshow(hp_filter, cmap='gray')

filtered_by_hp = np.real(F2*hp_filter)
plt.subplot(2, 2, 2)
plt.title('filtered magnitude')
plt.imshow(np.log(1 + np.abs(filtered_by_hp)), cmap='gray')

recon_filtered_by_hp = np.real(np.fft.ifft2(np.fft.ifftshift(filtered_by_hp)))
plt.subplot(2, 2, 3)
plt.imshow(recon_filtered_by_hp, cmap='gray')

plt.subplot(2, 2, 4)
plt.imshow(screen_shot, cmap='gray')

# %%
# TODO 2.2 : Implement an ideal low-pass filter with a box size of 100x100 pixels on the given image
n = 100
image_size = F2.shape
x, y = np.mgrid[-image_size[0]//2:image_size[0]//2, -image_size[1]//2:image_size[1]//2]

lp_filter = np.zeros_like(F2, dtype=np.int16)
lp_filter[(x<n//2) & (x>-n//2) & (y<n//2) & (y>-n//2)] = 1
lp_filter = np.real(lp_filter)
plt.subplot(2, 2, 1)
plt.title('high pass filter')
plt.imshow(lp_filter, cmap='gray')

filtered_by_hp = np.real(F2*lp_filter)
plt.subplot(2, 2, 2)
plt.title('filtered magnitude')
plt.imshow(np.log(1 + np.abs(filtered_by_hp)), cmap='gray')
recon_filtered_by_hp = np.real(np.fft.ifft2(np.fft.ifftshift(filtered_by_hp)))
plt.subplot(2, 2, 3)
plt.imshow(recon_filtered_by_hp, cmap='gray')

plt.subplot(2, 2, 4)
plt.imshow(screen_shot, cmap='gray')

# %% [markdown]
# ## Problem 3
#
# A digital signal can be generated from sampling of an analog signal using a periodic impulse-train. Explain how you can reconstruct an analog signal from a digital signal and aliasing problem does not occur when $f_s \leq 2f_{max} $ using frequency analysis.
#
# where $f_s$ is the sampling frequency and $f_{max} $ is the maximum frequency of the analog signal
#
# HINT :  $ \mathscr{F} \left\{ \sum_{n=-\infty}^{\infty} \delta (t-n T_s) \right\} = \sum_{n=-\infty}^{\infty} \delta(\omega - n\omega_s)$ if $\omega_s = \frac{2\pi}{T_s} = 2\pi f_s$

# %% [markdown]
# ## Problem 4 : Aliasing
#
# ### Problem 4.1
#
# The following code generates two sine waves (x01_ts01 and x02_ts01) which are sampled in a range of t = 0,0.05 with sampling rate = 5000 Hz (f_samp_01). Study and write a report to analyze the results.

# %%
t_st = 0
t_end = 0.05
f_01 = 200
f_02 = 2300

f_samp_01 = 5000

ts01 = np.linspace(t_st, t_end , int((t_end-t_st)*f_samp_01), endpoint=False)
x01_ts01 = np.sin(2*np.pi*f_01*ts01)
x02_ts01 = np.sin(2*np.pi*f_02*ts01)

plt.figure(figsize=(20, 5))
plt.plot(ts01, x01_ts01, 'go-', ts01, x02_ts01, 'r.-')
plt.show()

# %% [markdown]
# The sampling rate is reduced to 2500 Hz (f_samp_02). Study and write a report to compare the results.

# %%
f_samp_02 = 2500
ts02 = np.linspace(t_st, t_end , int((t_end-t_st)*f_samp_02), endpoint=False)
x01_ts02 = np.sin(2*np.pi*f_01*ts02)
x02_ts02 = np.sin(2*np.pi*f_02*ts02)

plt.figure(figsize=(20, 5))
plt.plot(ts02, x01_ts02, 'go-', ts02, x02_ts02, 'r.-')
plt.show()

# %% [markdown]
# Ans.

# %% [markdown]
# ### Problem 4.2
# The following code generate audio signals at different frequencies. Play the sound and write a report the analyse the results.

# %%
t_st = 0
t_end = 5
f_01 = 50
f_02 = 22050 - f_01
f_03 = 22050 + f_01
f_samp_02 = 22050

ts02 = np.linspace(t_st, t_end , int((t_end-t_st)*f_samp_02), endpoint=False)

# CREATE SIGNAL WITH DIFFERENT FREQ

x01_ts02 = np.sin(2*np.pi*f_01*ts02)
x02_ts02 = np.sin(2*np.pi*f_02*ts02)
x03_ts02 = np.sin(2*np.pi*f_03*ts02)

# %%
x02_ts02

# %%
ipd.Audio(x01_ts02, rate=f_samp_02)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(x02_ts02, rate=f_samp_02)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(x03_ts02, rate=f_samp_02)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <a href="https://imgflip.com/i/4djx2z"><img src="https://i.imgflip.com/4djx2z.jpg" title="made at imgflip.com"/></a><div><a href="https://imgflip.com/memegenerator">from Imgflip Meme Generator</a></div>

# %% [markdown]
# ###  TODO : write report
# Ans:

# %% [markdown]
# ### Problem 4.3
# ### why many of audio file use sampling rate 44.1 kHz
#
#
# Ans:

# %% [markdown]
# ### Problem 5
# Download the 3 audio files and analyze all 3 signals with preliminary analysis.
# (HINT : Use a log scale for both frequency and magnitude.)"
#
# 1. bass-guitar-single-note --> mixkit-bass-guitar-single-note-2331.wav
#
# explain pattern of signal

# %%
# !wget https://raw.githubusercontent.com/Pataweepr/ComEngMath2_2023_resource/master/mixkit-adult-sneeze-2212.wav
# !wget https://raw.githubusercontent.com/Pataweepr/ComEngMath2_2023_resource/master/mixkit-child-deep-breath-2237.wav
# !wget https://raw.githubusercontent.com/Pataweepr/ComEngMath2_2023_resource/master/mixkit-bass-guitar-single-note-2331.wav
